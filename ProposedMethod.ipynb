# %% [markdown]
# ## Importing the Libraries

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from os import listdir
import cv2
import numpy as np
from matplotlib import pyplot as plt

framObj = {'img': [], 'mask': []}

# defining data Loader function
def LoadData(frameObj=None, imgPath=None, maskPath=None, shape=256):
    imgNames = listdir(imgPath)
    maskNames = listdir(maskPath)

    images = []
    masks = []

    for i in range(len(imgNames)):
      images.append(imgNames[i] )
    for m in range(len(maskNames)):
      masks.append(maskNames[m] )

    images.sort()
    masks.sort()

    for i in range(10):
      print("Image : ",images[i])
      print("Masks : ",masks[i])

    imgAddr = imgPath + '/'
    maskAddr = maskPath + '/'

    for i in range(len(images)):
        img = plt.imread(imgAddr + images[i])
        mask = plt.imread(maskAddr + masks[i])

        img = cv2.resize(img, (shape, shape))
        mask = cv2.resize(mask, (shape, shape))
        '''

        img = np.clip(img - np.median(img)+127, 0, 255)
        img = img/255.0
        img = img.astype(np.float32)


        mask = mask.astype(np.float32)
        mask = mask/255.0
        '''

        frameObj['img'].append(img)
        frameObj['mask'].append(mask)

    return frameObj

# %%
framObj = LoadData(framObj,
                        imgPath='/content/drive/MyDrive/dataset/images' ,
                        maskPath='/content/drive/MyDrive/dataset/masks',
                        shape=256)
# Out:
# Image :  image (1).png
# Masks :  mask (1).png
# Image :  image (10).png
# Masks :  mask (10).png
# Image :  image (100).png
# Masks :  mask (100).png
# Image :  image (101).png
# Masks :  mask (101).png
# Image :  image (102).png
# Masks :  mask (102).png
# Image :  image (103).png
# Masks :  mask (103).png
# Image :  image (104).png
# Masks :  mask (104).png
# Image :  image (105).png
# Masks :  mask (105).png
# Image :  image (106).png
# Masks :  mask (106).png
# Image :  image (107).png
# Masks :  mask (107).png

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(framObj['img'], framObj['mask'], test_size = 0.10, random_state = 101)

# %%
print(np.shape(x_train))
print(np.shape(y_train))

# %%
print(np.shape(x_test))
print(np.shape(y_test))

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(x_train[10])
plt.subplot(2,4,2)
plt.imshow(x_train[20])
plt.subplot(2,4,3)
plt.imshow(x_train[30])
plt.subplot(2,4,4)
plt.imshow(x_train[40])
plt.subplot(2,4,5)
plt.imshow(x_train[50])
plt.subplot(2,4,6)
plt.imshow(x_train[60])
plt.subplot(2,4,7)
plt.imshow(x_train[70])
plt.subplot(2,4,8)
plt.imshow(x_train[80])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(y_train[10], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(y_train[20], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(y_train[30], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(y_train[40], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(y_train[50], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(y_train[60], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(y_train[70], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(y_train[80], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)

        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)

        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 100
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %%
# For test Set
x_test_full = np.concatenate([x_test, x_rotated_t, x_flipped_t])
y_test_full = np.concatenate([y_test, y_rotated_t, y_flipped_t])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val , y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 1396
# Length of the Test Set       : 65
# Length of the Validation Set : 350

# %%
print("Length of the Training Set   : {}".format(np.shape(x_train)))
print("Length of the Test Set       : {}".format(np.shape(x_test)))
print("Length of the Validation Set : {}".format(np.shape(x_val)))
# Out:
# Length of the Training Set   : (1396, 256, 256, 3)
# Length of the Test Set       : (65, 256, 256, 3)
# Length of the Validation Set : (350, 256, 256, 3)

# %% [markdown]
# ## Architecture of the proposed Method

# %% [markdown]
# Import Required Libraries

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.applications import *

# %%
def conv_block(inputs, filters):
    x = inputs

    x = Conv2D(filters, (3, 3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

# %%
def encoder(inputs):
    skip_connections = []

    model = EfficientNetB7(include_top=False, weights='imagenet', input_tensor=inputs)
    names = ["input_2", "block2a_expand_activation", "block3a_expand_activation", "block4a_expand_activation"]
    for name in names:
        skip_connections.append(model.get_layer(name).output)

    output = model.get_layer("block5a_expand_activation").output
    return output, skip_connections

# %%
def decoder(inputs, skip_connections):
    num_filters = [256, 128, 64, 32]
    skip_connections.reverse()
    x = inputs

    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation='bilinear')(x)
        x = Concatenate()([x, skip_connections[i]])
        x = conv_block(x, f)

    return x

# %%
def output_block(inputs):
    x = Conv2D(1, (1, 1), padding="same")(inputs)
    x = Activation('sigmoid')(x)
    return x

# %%
def Upsample(tensor, size):
    """Bilinear upsampling"""
    def _upsample(x, size):
        return tf.image.resize(images=x, size=size)
    return Lambda(lambda x: _upsample(x, size), output_shape=size)(tensor)

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation='bilinear')(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=6, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=12, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=18, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
def build_model(shape):
    inputs = Input(shape)
    x, skip_1 = encoder(inputs)
    x = ASPP(x, 64)
    x = decoder(x, skip_1)
    outputs = output_block(x)

    model = Model(inputs, outputs)
    return model

# %%
model = build_model((256, 256, 3))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 256, 256, 3)  0           ['input_2[0][0]']
#
#  normalization_1 (Normalization  (None, 256, 256, 3)  7          ['rescaling_1[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 257, 257, 3)  0           ['normalization_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 128, 128, 64  1728        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 128, 128, 64  256         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 128, 128, 64  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 128, 128, 64  576        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 128, 128, 64  256        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 128, 128, 64  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 128, 128, 64  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 128, 128, 32  2048        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 128, 128, 32  288        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 128, 128, 32  128        ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 128, 128, 32  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 128, 128, 32  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 128, 128, 32  1024        ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 128, 128, 32  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 128, 128, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 128, 128, 32  288        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 128, 128, 32  128        ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 128, 128, 32  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 128, 128, 32  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 128, 128, 32  1024        ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 128, 128, 32  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 128, 128, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 128, 128, 32  288        ['block1c_add[0][0]']
#  D)                             )
#
#  block1d_bn (BatchNormalization  (None, 128, 128, 32  128        ['block1d_dwconv[0][0]']
#  )                              )
#
#  block1d_activation (Activation  (None, 128, 128, 32  0          ['block1d_bn[0][0]']
#  )                              )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 128, 128, 32  0           ['block1d_activation[0][0]',
#                                 )                                 'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 128, 128, 32  1024        ['block1d_se_excite[0][0]']
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block1d_project_conv[0][0]']
#  lization)                      )
#
#  block1d_drop (Dropout)         (None, 128, 128, 32  0           ['block1d_project_bn[0][0]']
#                                 )
#
#  block1d_add (Add)              (None, 128, 128, 32  0           ['block1d_drop[0][0]',
#                                 )                                 'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block1d_add[0][0]']
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2a_expand_conv[0][0]']
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 128, 128, 19  0          ['block2a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 129, 129, 19  0          ['block2a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 64, 64, 192)  1728       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 64, 64, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 64, 64, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 64, 64, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 64, 64, 48)   9216        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 64, 64, 288)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 64, 64, 288)  2592       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 64, 64, 288)  1152       ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 64, 64, 288)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 64, 64, 288)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 64, 64, 48)   13824       ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 64, 64, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 64, 64, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 64, 64, 288)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 64, 64, 288)  2592       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 64, 64, 288)  1152       ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 64, 64, 288)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 64, 64, 288)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 64, 64, 48)   13824       ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 64, 64, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 64, 64, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 64, 64, 288)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 64, 64, 288)  2592       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 64, 64, 288)  1152       ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 64, 64, 288)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 64, 64, 288)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 64, 64, 48)   13824       ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 64, 64, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 64, 64, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 64, 64, 288)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 64, 64, 288)  2592       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 64, 64, 288)  1152       ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 64, 64, 288)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 64, 64, 288)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 64, 64, 48)   13824       ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 64, 64, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 64, 64, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 64, 64, 288)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 64, 64, 288)  2592       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 64, 64, 288)  1152       ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 64, 64, 288)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 64, 64, 288)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 64, 64, 48)   13824       ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 64, 64, 48)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 64, 64, 48)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 64, 64, 288)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 64, 64, 288)  2592       ['block2g_expand_activation[0][0]
#  D)                                                              ']
#
#  block2g_bn (BatchNormalization  (None, 64, 64, 288)  1152       ['block2g_dwconv[0][0]']
#  )
#
#  block2g_activation (Activation  (None, 64, 64, 288)  0          ['block2g_bn[0][0]']
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 64, 64, 288)  0           ['block2g_activation[0][0]',
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 64, 64, 48)   13824       ['block2g_se_excite[0][0]']
#
#  block2g_project_bn (BatchNorma  (None, 64, 64, 48)  192         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (Dropout)         (None, 64, 64, 48)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 64, 64, 48)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 64, 64, 288)  13824       ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 64, 64, 288)  1152       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 64, 64, 288)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 67, 67, 288)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 32, 32, 288)  7200       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 32, 32, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 32, 32, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 32, 32, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 32, 32, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 32, 32, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 32, 32, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 32, 32, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 32, 32, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 32, 32, 480)  12000      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 32, 32, 480)  1920       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 32, 32, 480)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 480)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 32, 32, 480)  0           ['block3b_activation[0][0]',
# ...
#  block5a_expand_conv (Conv2D)   (None, 16, 16, 960)  153600      ['block4j_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 16, 16, 960)  3840       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 16, 16, 960)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  average_pooling2d (AveragePool  (None, 1, 1, 960)   0           ['block5a_expand_activation[0][0]
#  ing2D)                                                          ']
#
#  conv2d (Conv2D)                (None, 1, 1, 64)     61504       ['average_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 1, 64)    256         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   61440       ['block5a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 64)   552960      ['block5a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 64)   552960      ['block5a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 64)   552960      ['block5a_expand_activation[0][0]
#                                                                  ']
#
#  activation (Activation)        (None, 1, 1, 64)     0           ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_2[0][0]']
#
#  activation_3 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_3[0][0]']
#
#  activation_4 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 320)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_1[0][0]',
#                                                                   'activation_2[0][0]',
#                                                                   'activation_3[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   20480       ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)  0           ['activation_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 544)  0           ['up_sampling2d_1[0][0]',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  1253632     ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0          ['activation_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 544)  0           ['up_sampling2d_2[0][0]',
#                                                                   'block3a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  626816      ['concatenate_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 12  0          ['activation_9[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['up_sampling2d_3[0][0]',
#                                 0)                                'block2a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 64  184384      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 64  36928       ['activation_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_11 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 64  0          ['activation_11[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 67  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'input_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 32  19328       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 32  9248        ['activation_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 1)  33          ['activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 256, 256, 1)  0           ['conv2d_14[0][0]']
#
# ==================================================================================================
# Total params: 9,599,616
# Trainable params: 9,532,473
# Non-trainable params: 67,143
# __________________________________________________________________________________________________

# %%
model.compile(optimizer= Adam(learning_rate=1e-4), loss= dice_loss
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
#model.summary()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=20)
mc = ModelCheckpoint('best_model_model.h5',
                     monitor='val_accuracy',
                     mode='max', verbose=1,
                     save_best_only=True)

# %%
import datetime
now = datetime.datetime.now
t = now()
hist = model.fit(x_train, y_train, epochs= 100, batch_size= 18,callbacks=[mc,es], validation_data= (x_val, y_val), verbose=1)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/100
# 78/78 [==============================] - ETA: 0s - loss: 0.7121 - iou: 0.6966 - dice_coef: 0.2884 - precision: 0.2235 - recall: 0.8709 - accuracy: 0.6729
# Epoch 00001: val_accuracy improved from -inf to 0.09222, saving model to best_model_model.h5
# 78/78 [==============================] - 95s 943ms/step - loss: 0.7121 - iou: 0.6966 - dice_coef: 0.2884 - precision: 0.2235 - recall: 0.8709 - accuracy: 0.6729 - val_loss: 0.8297 - val_iou: 0.3567 - val_dice_coef: 0.1688 - val_precision: 0.0908 - val_recall: 1.0000 - val_accuracy: 0.0922
# Epoch 2/100
# 78/78 [==============================] - ETA: 0s - loss: 0.6317 - iou: 0.8072 - dice_coef: 0.3676 - precision: 0.3493 - recall: 0.8542 - accuracy: 0.8400
# Epoch 00002: val_accuracy improved from 0.09222 to 0.28815, saving model to best_model_model.h5
# 78/78 [==============================] - 68s 870ms/step - loss: 0.6317 - iou: 0.8072 - dice_coef: 0.3676 - precision: 0.3493 - recall: 0.8542 - accuracy: 0.8400 - val_loss: 0.8043 - val_iou: 0.4442 - val_dice_coef: 0.1941 - val_precision: 0.1101 - val_recall: 0.9687 - val_accuracy: 0.2881
# Epoch 3/100
# 78/78 [==============================] - ETA: 0s - loss: 0.5862 - iou: 0.8502 - dice_coef: 0.4138 - precision: 0.4574 - recall: 0.8586 - accuracy: 0.8935
# Epoch 00003: val_accuracy improved from 0.28815 to 0.71148, saving model to best_model_model.h5
# 78/78 [==============================] - 68s 870ms/step - loss: 0.5862 - iou: 0.8502 - dice_coef: 0.4138 - precision: 0.4574 - recall: 0.8586 - accuracy: 0.8935 - val_loss: 0.7550 - val_iou: 0.6521 - val_dice_coef: 0.2432 - val_precision: 0.1923 - val_recall: 0.6805 - val_accuracy: 0.7115
# Epoch 4/100
# 78/78 [==============================] - ETA: 0s - loss: 0.5448 - iou: 0.8759 - dice_coef: 0.4552 - precision: 0.5296 - recall: 0.8818 - accuracy: 0.9168
# Epoch 00004: val_accuracy improved from 0.71148 to 0.90351, saving model to best_model_model.h5
100
# 78/78 [==============================] - ETA: 0s - loss: 0.0281 - iou: 0.9948 - dice_coef: 0.9719 - precision: 0.9784 - recall: 0.9788 - accuracy: 0.9957
# Epoch 00060: val_accuracy did not improve from 0.94873
# 78/78 [==============================] - 66s 847ms/step - loss: 0.0281 - iou: 0.9948 - dice_coef: 0.9719 - precision: 0.9784 - recall: 0.9788 - accuracy: 0.9957 - val_loss: 0.4086 - val_iou: 0.9183 - val_dice_coef: 0.5903 - val_precision: 0.6979 - val_recall: 0.5242 - val_accuracy: 0.9357
# Epoch 00060: early stopping
# Training time: 1:06:38.287283

# %% [markdown]
# ## Loading the Model

# %%
print(np.shape(x_test_full))
print(np.shape(y_test_full))
# Out:
# (195, 256, 256, 3)
# (195, 256, 256)

# %%
print(np.shape(x_val))
print(np.shape(y_val))
# Out:
# (350, 256, 256, 3)
# (350, 256, 256)

# %%
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# (1396, 256, 256, 3)
# (1396, 256, 256)

# %%
model.load_weights('./best_model_model.h5')

# %%
print('\n-------------On Train Set--------------------------\n')
res = model.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')

print('\n-------------On validation Set---------------------\n')
res = model.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')

print('\n-------------On Test  Set--------------------------\n')
res = model.evaluate(x_test_full, y_test_full, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# -------------On Train Set--------------------------
#
# 78/78 [==============================] - 13s 162ms/step - loss: 0.0598 - iou: 0.9907 - dice_coef: 0.9401 - precision: 0.9837 - recall: 0.9376 - accuracy: 0.9925
# ________________________
# IOU:       |   99.07  |
# Dice Coef: |   94.01  |
# Precision: |   98.37  |
# Recall:    |   93.76  |
# Accuracy:  |   99.25  |
# Loss:      |   5.98  |
# ________________________
#
# -------------On validation Set---------------------
#
# 20/20 [==============================] - 3s 159ms/step - loss: 0.3527 - iou: 0.9378 - dice_coef: 0.6433 - precision: 0.8321 - recall: 0.5488 - accuracy: 0.9487
# ________________________
# IOU:       |   93.78  |
# Dice Coef: |   64.33  |
# Precision: |   83.21  |
# Recall:    |   54.88  |
# Accuracy:  |   94.87  |
# Loss:      |   35.27  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 11/11 [==============================] - 2s 226ms/step - loss: 0.4062 - iou: 0.9286 - dice_coef: 0.5957 - precision: 0.7995 - recall: 0.4992 - accuracy: 0.9436
# ________________________
# IOU:       |   92.86  |
# Dice Coef: |   59.57  |
# Precision: |   79.95  |
# Recall:    |   49.92  |
# Accuracy:  |   94.36  |
# Loss:      |   40.62  |
# ________________________

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %%
# Get training and test loss histories
training_loss = hist.history['loss']
test_loss = hist.history['val_loss']
training_acc = hist.history['accuracy']
test_acc = hist.history['val_accuracy']
# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
plt.grid(color='gray', linestyle='--')
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()


# Visualize accuracy history
plt.plot(epoch_count, training_acc, 'r--')
plt.plot(epoch_count, test_acc, 'b-')
plt.grid(color='gray', linestyle='--')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model.predict(x_test[img_num].reshape(1,256,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(256, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model.predict(x_test[img_num].reshape(1,256,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(256, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model.predict(x_test[img_num].reshape(1,256,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(256, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model.predict(x_test[img_num].reshape(1,256,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(256, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model.predict(x_test[img_num].reshape(1,256,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(256, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model.predict(x_test[img_num].reshape(1,256,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(256, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model.predict(img.reshape(1,256,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(256,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(256,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(256,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()
